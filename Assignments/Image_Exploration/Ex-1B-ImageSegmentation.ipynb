# %% [markdown]
# ### Task
#
# Imagine that you are a data analyst at a company that sells inflatable pool donuts. Your next task is to determine which color of donuts people like the most. Try to analyse the images for the pool donuts!

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import os
import cv2
import scipy.signal

from sklearn.cluster import KMeans
from collections import Counter
from skimage.color import rgb2lab, deltaE_cie76

from ipywidgets import interact

#plt.rcParams['text.usetex'] = True

# https://pypi.org/project/python-dotenv/
from dotenv import load_dotenv
load_dotenv("env_variables")
# Out:
# True

# %% [markdown]
# ### Load images

# %%
DATASET_DIR = os.getenv('DATASET_DIR')
imagedir = f"{DATASET_DIR}/Image_Exploration/"

# %%
# f, axs = plt.subplots(3, 1, figsize=(15, 10))
# for i in range(1, 4):
#     img = cv2.imread(os.path.join(imagedir, 'stuffed_pool%d.png'%i))
#     pool = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#     axs[i-1].imshow(pool)
# plt.show()

# %%
imgs = [cv2.imread(os.path.join(imagedir, 'stuffed_pool%d.png'%i)) for i in range(1, 4)]
pool_imgs = [cv2.cvtColor(img, cv2.COLOR_BGR2RGB) for img in imgs]

# %%
def show_images(i):
    plt.imshow(pool_imgs[i])
    plt.show()

# %%
interact(show_images, i=(0,2,1))
# Out:
# interactive(children=(IntSlider(value=1, description='i', max=2), Output()), _dom_classes=('widget-interact',)…
# <function __main__.show_images(i)>
